# %% [markdown]
# <a href="https://colab.research.google.com/github/ismael-acr/CienciadeDatos/blob/main/Princpial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from def_grafico import grafico_dispersion

#Cargar y solucionar el problema de la coma por punto, sin modificar nada
df = pd.read_csv("dataset_set_A_aguas_residuales.csv", sep=';', decimal=',')

#Llamar a la funcion
grafico_dispersion(df)
